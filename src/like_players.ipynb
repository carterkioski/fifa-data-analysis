# %%
import pandas as pd

# %%
all_players_df = pd.read_csv('../data/cleaned_all.csv',low_memory=False).iloc[:,1:]

# %%
all_players_df
# Out:
#                                Name Nationality  Age  Overall  \
# 0                      Lionel Messi   Argentina   33       93
# 1      C. Ronaldo dos Santos Aveiro    Portugal   35       92
# 2                         Jan Oblak    Slovenia   27       91
# 3                   Kevin De Bruyne     Belgium   29       91
# 4        Neymar da Silva Santos Jr.      Brazil   28       91
# ...                             ...         ...  ...      ...
# 18974                        Ao Xia    China PR   21       47
# 18975                     Ben Hough     England   17       47
# 18976                Ronan McKinley     England   18       47
# 18977                  Zhen'ao Wang    China PR   20       47
# 18978                     Xiao Zhou    China PR   21       47
#
#                       Club  Height(cm)  Weight(km) Preferred Foot Position  \
# 0             FC Barcelona       170.0        72.0           Left       RW
# ...

# %%
#KNN for players similar to eachother
